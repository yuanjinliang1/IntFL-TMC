# %%
import torch
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
clientNum100_round0_localEpoch100 = np.load('id_samples_acc_loss-clientNum100-round0-localEpoch100.npy', allow_pickle=True)
# clientNum100_round0_localEpoch100[0]
clientNum100_round0_localEpoch100_sort = sorted(clientNum100_round0_localEpoch100, key = lambda kv:kv['acc'])
clientNum100_round0_localEpoch100_sort
# Out:
# [{'client_id': '54',
#   'num_train_samples': 534,
#   'acc': 15.69,
#   'loss': 0.1437199983257174},
#  {'client_id': '8',
#   'num_train_samples': 578,
#   'acc': 16.49,
#   'loss': 1.67562504070131},
#  {'client_id': '86',
#   'num_train_samples': 514,
#   'acc': 16.75,
#   'loss': 1.513282213023273},
#  {'client_id': '91',
#   'num_train_samples': 323,
#   'acc': 17.26,
#   'loss': 1.3759271468667331},
#  {'client_id': '18',
#   'num_train_samples': 250,
#   'acc': 18.72,
#   'loss': 0.9825643047881126},
#  {'client_id': '24',
#   'num_train_samples': 770,
#   'acc': 19.4,
#   'loss': 1.317498666621261},
#  {'client_id': '90',
#   'num_train_samples': 168,
#   'acc': 19.44,
#   'loss': 1.4865403581233252},
#  {'client_id': '1',
#   'num_train_samples': 110,
#   'acc': 19.53,
#   'loss': 1.371641350361434},
#  {'client_id': '61',
#   'num_train_samples': 1027,
#   'acc': 19.81,
#   'loss': 0.7823512000336286},
#  {'client_id': '88',
#   'num_train_samples': 178,
#   'acc': 19.89,
# ...
